# %%
import pandas as pd

# %%
final_df = pd.read_csv('../data/recipe_200_with_classification.csv')

final_df.head(26)
# Out:
#         id                                              title    cook_time  \
# 0    32204                whatever floats your boat  brownies       35mins
# 1   107997                       4 minute spicy garlic shrimp       17mins
# 2   132263                            5 minute vegan pancakes       15mins
# 3    28768                         absolute best ever lasagna  2hrs 30mins
# 4    29598                           amazing chicken marinade       35mins
# 5   108231                      amazing chicken tortilla soup   1hr 15mins
# 6    53878                     amazing white trash puff balls       31mins
# 7    92095                        authentic italian meatballs  3hrs 20mins
# 8    46922                                  awesome baked ham  4hrs 20mins
# 9    34499                           awesome baked pork chops  2hrs 30mins
# 10   57130                      awesome slow cooker pot roast  8hrs 10mins
# ...
