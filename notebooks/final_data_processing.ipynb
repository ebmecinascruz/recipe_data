# %%
import pandas as pd

# %%
final_df = pd.read_csv('../data/recipe_200_processed.json_ready.csv')

final_df.head()
# Out:
#    recipe_id  creator_id                            title_raw  \
# 0      32204       37305  whatever floats your boat  brownies
# 1     107997       52074         4 minute spicy garlic shrimp
# 2     132263      233464              5 minute vegan pancakes
# 3      28768       37779           absolute best ever lasagna
# 4      29598       35193             amazing chicken marinade
#
#                                    title  \
# 0  "Whatever Floats Your Boat" Brownies!
# 1           4 Minute Spicy Garlic Shrimp
# 2                5 Minute Vegan Pancakes
# 3             Absolute Best Ever Lasagna
# 4               Amazing Chicken Marinade
#
#                                          description  \
# 0  These are absolutely the chewiest, moistest, f...
# 1  Recipe is originally from the Food Network cou...
# 2  A cinch to make and tastes wonderful, if you l...
# 3  My family's favorite. This is a very meaty las...
# 4  This recipe came from Allrecipes (Ruth Crickme...
#
# ...

# %%
final_df[final_df['servings'].isna()]
# Out:
#      recipe_id  creator_id                                          title_raw  \
# 121      15865       15609  p  f  chang s chicken lettuce wraps by todd wi...
# 122      66121        3288        p  f  chang s mongolian beef by todd wilbur
# 184     102274       74652  tsr version of t g i  friday s black bean soup...
#
#                                                  title description  \
# 121  p  f  chang s chicken lettuce wraps by todd wi...         NaN
# 122        p  f  chang s mongolian beef by todd wilbur         NaN
# 184  tsr version of t g i  friday s black bean soup...         NaN
#
#     ingredients instructions cook_time servings  \
# 121          []           []       NaN      NaN
# 122          []           []       NaN      NaN
# 184          []           []       NaN      NaN
#
#                                                   tags   cuisine difficulty
# 121  ['lactose', '30-minutes-or-less', 'time-to-mak...     Asian     Medium
# ...

# %%
reviews_df = pd.read_csv('../data/final_interactions.csv')

# %%
len(reviews_df)
# Out:
# 1659

# %%
reviews_df[reviews_df['recipe_id'] == 63689]
# Out:
#      user_id  recipe_id        date  rating  \
# 150    80353      63689  2003-08-20       5
# 151    88099      63689  2004-09-08       4
# 152   173579      63689  2004-11-19       5
# 153   160974      63689  2004-12-22       5
# 154   222564      63689  2006-10-14       4
# 155     8688      63689  2007-04-24       5
# 156   169969      63689  2007-09-12       5
# 157   176615      63689  2007-12-25       5
# 158   140132      63689  2008-01-19       5
# 159   101823      63689  2008-04-27       5
# 160   126440      63689  2013-01-30       4
# 161   204024      63689  2013-09-30       5
# 162   560491      63689  2013-10-04       4
# 163    47892      63689  2014-02-04       4
# 164   461834      63689  2014-02-05       5
#
#                                                 review
# 150  These really are good sloppy joes and much-enj...
# 151  These were wonderful.  I also cut down on the ...
# 152  My family loves these.  They have wonderful fl...
# ...
